# %% [markdown]
# # B404B Modern Issues in Finance: Computational Finance in Python
# *Submission Date: June 29, 2025*
#
# This notebook contains the code and explanations of **group 2** for the assessment in the course **B404B Modern Issues in Finance: Computational Finance in Python**.
#
# **Members in Group 2**
#
# * Aaron Sennhenn
# * Liqian Huang
# * Nino Maisuradze
# * Xuan Yang
#
#
# **Table of Contents**
#
#
# 1. [Data Acquisition](#setup)
# 2. [Definition of Signals](#I)
# 3. [Computation of Signals and Resulting Positions](#II)
# 4. [Statistics of the Strategy](#III)
# 5. [Graphs of Strategy](#IV)

# %% [markdown]
# ## Data Acquisition

# %%
import numpy as np
import pandas as pd
import pandas_datareader.data as web
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

from module import *

# %%
# define tickers of stocks that are to be analyzed
tickers = [ \
    'AAPL', #Apple
    'AMD',  #AMD
    'TSLA', #TSLA
    '^GSPC'] # S&P500 - Benchmark

# define time span of stock price data
start_date = '2020-01-01'
end_date = '2024-12-31'

# download the data
df_prices, df_price_changes = download_stock_price_data(tickers, start_date, end_date)
# Out:
# [*********************100%***********************]  4 of 4 completed

# %% [markdown]
# ## Definition of Signals <a id="I"></a>

# %% [markdown]
# This section details the construction and rationale behind the three composite trading signals employed in our strategy. Each signal is meticulously designed to capitalize on specific market phenomena by integrating distinct categories of technical indicators. This approach aims to enhance signal robustness, mitigate false positives, and ultimately contribute to maximizing risk-adjusted returns. For each composite signal, we elucidate its core idea, define its constituent sub-signals, provide the specific mathematical formulations of the underlying indicators, and present the strategy rationales and advantages.
#
# **Note that in the following definitions, generic parameter values are used as placeholders for generalization purposes. Within the "Computation of Signals and Resulting Positions" section, the *actual* optimized parameters for each Stock/Signal combination are defined via code and used to generate the signals.**

# %% [markdown]
# ### Signal 1: Trend-Following with Momentum

# %% [markdown]
# This strategy combines a long-term trend filter (Dual SMA Crossover) with a mid-term momentum trigger (MACD) to identify high-probability, trend-aligned trades.

# %% [markdown]
# #### Long-Term Trend Filter: Dual Moving Average (SMA) Crossover

# %% [markdown]
# This sub-signal establishes the primary market direction.
#
# * **Indicator:** 50-day & 200-day Simple Moving Averages (SMA).
# * **Logic:**
#   * **Bullish Trend:** SMA50 > SMA200
#   * **Bearish Trend:** SMA50 < SMA200
# * **Formula:**
#   > $$\text{SMA}_N(t) = \frac{1}{N} \sum_{i=0}^{N-1} P_{t-i}$$
# * **Rationale:** Acts as a robust filter to ensure trades are only considered in the direction of the dominant market trend, effectively reducing counter-trend risk.

# %% [markdown]
# #### Mid-Term Momentum Trigger: MACD

# %% [markdown]
# This sub-signal provides the precise timing for entry and exit.
#
# * **Indicator:** Moving Average Convergence Divergence (MACD) with standard (12, 26, 9) parameters.
# * **Logic:**
#   * **Buy Trigger:** MACD Line crosses **above** Signal Line.
#   * **Sell Trigger:** MACD Line crosses **below** Signal Line.
# * **Core Formulas:**
#   > $$\text{MACD Line} = \text{EMA}_{12}(P_t) - \text{EMA}_{26}(P_t)$$
#   > $$\text{Signal Line} = \text{EMA}_{9}(\text{MACD Line})$$
# * **Rationale:** Pinpoints actionable shifts in momentum, serving as the confirmation needed to execute a trade within the established long-term trend.

# %% [markdown]
# #### Combined Signal Rule

# %% [markdown]
# The final trading decision is based on the synergy of both sub-signals.
#
# * **BUY Signal:** (SMA50 > SMA200) **OR** (MACD Line crosses above Signal Line)
# * **SELL Signal:** (SMA50 < SMA200) **AND** (MACD Line crosses below Signal Line)
# * **HOLD:** All other conditions.

# %% [markdown]
# **Key Advantages**
#
# * **Reduces Whipsaws:** The trend filter effectively ignores false momentum signals that occur against the primary market direction.
# * **Improves Signal Quality:** By demanding both trend alignment and momentum confirmation, the strategy focuses only on high-conviction trades, aiming for a higher win rate.

# %%
### Signal 1

def signal01(prices, short_ma, long_ma, short_macd, long_macd, signal_window_macd):

    #MA Signal
    ma_sig = ma_signal(prices, short_ma, long_ma)

    #MACD Signal
    macd_sig = signal_macd(prices, short_macd, long_macd, signal_window_macd)

    #Combine Signals
    combined = combine_two_subsignals(ma_sig['signal'], macd_sig['signal'])

    #Return combined signal dataframe
    signals = pd.DataFrame(index=prices.index)
    signals['signal'] = combined
    signals['position_change'] = signals['signal'].diff().fillna(0)
    signals['ma_position_change'] = ma_sig['position_change']
    signals['macd_position_change'] = macd_sig['position_change']

    return signals

# %% [markdown]
# ### Signal 2: Mean Reversion & Volatility

# %% [markdown]
# This strategy aims to capture mean-reversion bounces from oversold conditions, using volatility stabilization as a confirmation to avoid "catching a falling knife."

# %% [markdown]
# #### Oversold Identifier: Relative Strength Index (RSI)

# %% [markdown]
# This sub-signal identifies when an asset's price has moved to an extreme, suggesting a potential reversal.
#
# * **Indicator:** 14-day Relative Strength Index (RSI).
# * **Logic:**
#   * **Oversold Zone:** RSI < 30
#   * **Overbought Zone:** RSI > 70
# * **Core Formula:**
#   > $$\text{RSI} = 100 - \frac{100}{1 + \text{RS}}, \quad \text{where RS} = \frac{\text{Average Gain}}{\text{Average Loss}}$$
# * **Rationale:** Operates on the principle of mean reversion, where extreme price movements away from the average are statistically likely to correct.

# %% [markdown]
# #### Stabilization Trigger: Bollinger Bands

# %% [markdown]
# This sub-signal confirms that extreme price pressure is subsiding before a trade is placed.
#
# * **Indicator:** Bollinger Bands (20-day SMA, 2 Standard Deviations).
# * **Logic:**
#   * **Buy Trigger:** Price crosses back **above** the Lower Band after trading below it.
#   * **Sell Trigger:** Price crosses back **below** the Upper Band after trading above it.
# * **Core Formula:**
#   > $$\text{Upper/Lower Band} = \text{SMA}_{20}(P_t) \pm 2 \times \text{StdDev}_{20}(P_t)$$
# * **Rationale:** Provides confirmation that volatility is stabilizing and the intense selling (or buying) pressure has momentarily paused, offering a safer entry point.

# %% [markdown]
# #### Combined Signal Rule

# %% [markdown]
# The final trading decision requires both an extreme condition and a stabilization signal.
#
# * **BUY Signal:** (RSI < 30) **OR** (Price crosses back above Lower Bollinger Band)
# * **SELL Signal:** (RSI > 70) **AND** (Price crosses back below Upper Bollinger Band)
#
#
#
# **Key Advantages**
#
# * **Avoids "Catching a Falling Knife":** The Bollinger Band trigger acts as a safety check, preventing buys into an asset that is still in a strong downtrend, even if the RSI is low.
# * **Built-in Volatility Management:** By waiting for price to re-enter the bands, the strategy inherently avoids trading during the most chaotic phases of a price move, making it suitable for volatile assets.

# %%
### SIGNAL 2

def signal02(prices, rsi_window_length, lower_rsi_bound, upper_rsi_bound, bollinger_window_length, bollinger_n_stds):

    #RSI Signal
    rsi_sig= signal_rsi(prices, rsi_window_length, lower_rsi_bound, upper_rsi_bound)

    #Bollinger Signal
    bollinger_sig = signal_bollinger(prices, bollinger_window_length, bollinger_n_stds)

    #Combine Signals
    combined = combine_two_subsignals(rsi_sig['signal'], bollinger_sig['signal'])

    #Return combined signal dataframe
    signals = pd.DataFrame(index=prices.index)
    signals['signal'] = combined
    signals['position_change'] = signals['signal'].diff().fillna(0)
    signals['rsi_position_change'] = rsi_sig['position_change']
    signals['bollinger_position_change'] = bollinger_sig['position_change']

    return signals

# %% [markdown]
# ### Signal 3: Breakout & Trend Strength

# %% [markdown]
# This strategy aims to capture the beginning of new, powerful trends by confirming price breakouts with a measure of underlying trend strength, filtering out false signals.

# %% [markdown]
# #### Breakout Trigger: Donchian Channel
#
# This sub-signal provides the initial trigger when price moves beyond its recent range.
#
# * **Indicator:** 20-day Donchian Channel.
# * **Logic:**
#   * **Buy Trigger:** Price closes **above** the Upper Channel Band (a new 20-day high).
#   * **Sell Trigger:** Price closes **below** the Lower Channel Band (a new 20-day low).
# * **Core Formula:**
#   > $$\text{Upper Band} = \text{Highest High over past 20 periods}$$
#   > $$\text{Lower Band} = \text{Lowest Low over past 20 periods}$$
# * **Rationale:** Provides a clear, objective signal that price has broken out of its recent trading range, indicating a potential new trend.

# %% [markdown]
# #### Trend Strength Confirmation: ADX
#
# This sub-signal validates the conviction behind the breakout.
#
# * **Indicator:** 14-period Average Directional Index (ADX).
# * **Logic:**
#   * **Strong Trend:** ADX > 25
#   * **Weak / No Trend:** ADX < 25
# * **Core Concept:**
#   > ADX is derived from smoothed measures of positive (+DI) and negative (-DI) directional movement. It does not indicate direction, only strength.
# * **Rationale:** Measures the *strength* of a trend, regardless of whether it is bullish or bearish. It acts as a critical filter to confirm a breakout has genuine force behind it.

# %% [markdown]
# #### Combined Signal Rule

# %% [markdown]
# The final trading decision requires both a breakout and confirmed trend strength.
#
# * **BUY Signal:** (Price breaks above Upper Donchian Channel) **AND** (ADX > 25)
# * **SELL Signal:** (Price breaks below Lower Donchian Channel) **AND** (ADX > 25)
#
# **Key Advantages**
#
# * **Filters "Fakeouts":** The ADX requirement helps distinguish genuine, powerful breakouts from low-conviction moves that are likely to fail and reverse.
# * **Captures Early Trend Initiation:** Designed to enter at the beginning of major, sustainable moves, aiming to maximize profit from the entirety of a new trend.

# %%
### SIGNAL 3

def signal03(prices, adx_window_length, adx_threshhold, donchian_window_length):

    signals = pd.DataFrame(index=prices.index)
    signals['signal'] = 0.0

    adx = compute_adx(prices, adx_window_length)
    donchian_sig = donchian_signals(prices, donchian_window_length)
    donchian_sig_array = np.asarray(donchian_sig['signal'])

    position = np.zeros(len(prices), dtype=float)
    holding = 0
    for i in range(len(prices)):
        if np.isnan(adx[i]):
            continue
        if holding == 0 and donchian_sig_array[i] == 1 and adx[i] > adx_threshhold:
            holding = 1
        elif holding == 1 and donchian_sig_array[i] == 0 and adx[i] > adx_threshhold:
            holding = 0
        position[i] = holding

    signals['signal'] = position
    signals['position_change'] = signals['signal'].diff().fillna(0)
    signals['donchian_position_change'] = donchian_sig['position_change']
    signals.iloc[0, signals.columns.get_loc('position_change')] = 0

    return signals

# %% [markdown]
# ## Computation of Signals and Resulting Positions

# %% [markdown]
# **Strategy Analysis and Allocation**
#
# Based on a comprehensive evaluation of the assessment sample (2020-2025), we assigned a unique, best-fitting strategy to each of the three stocks to construct a strategy-diversified portfolio.
#
# First, the standout **mean-reversion strategy (Signal 2)** was allocated to the highly cyclical stock, **AMD**, which frequently oscillates within defined ranges. This pairing effectively captured short-term pullbacks, delivering a Sharpe Ratio of 2.67 and a cumulative return of 9,536%, significantly outperforming the benchmark.
#
# Next, for the high-volatility **Tesla (TSLA)**, known for its explosive breakout trends, we applied the **trend-breakthrough strategy (Signal 3)**. This combination capitalized on TSLA’s momentum-driven surges, resulting in a Sharpe Ratio of 1.90 and 3,719% cumulative return.
#
# Finally, the classic **trend-following strategy (Signal 1)** was applied to the more stable, mature growth stock, **Apple (AAPL)**, achieving a superior risk-adjusted return over the "Buy and Hold" strategy with a Sharpe Ratio of 1.08.
#
# This configuration creates a portfolio diversified by strategy, leveraging three different logics—mean reversion, trend breakthrough, and trend following—to systematically address the distinct market behavior of each stock.

# %%
#Define signal parameters
sig01_params = {'short_ma': 60, 'long_ma': 250, 'short_macd': 16, 'long_macd': 32, 'signal_window_macd': 9}
sig02_params = {'rsi_window_length': 18, 'lower_rsi_bound': 20, 'upper_rsi_bound': 60, 'bollinger_window_length': 14, 'bollinger_n_stds': 1}
sig03_params = {'adx_window_length': 10, 'adx_threshhold': 22, 'donchian_window_length': 10}

# %%
# Compute signals
signals = {
    tickers[0]: signal01(prices = df_prices[tickers[0]], **sig01_params),
    tickers[1]: signal02(prices = df_prices[tickers[1]], **sig02_params),
    tickers[2]: signal03(prices = df_prices[tickers[2]], **sig03_params)}
df_position_open = pd.concat([
    signals[tickers[0]]['signal'].rename(tickers[0]),
    signals[tickers[1]]['signal'].rename(tickers[1]),
    signals[tickers[2]]['signal'].rename(tickers[2])], axis = 1)
df_position_changes = pd.concat([
    signals[tickers[0]]['position_change'].rename(tickers[0]),
    signals[tickers[1]]['position_change'].rename(tickers[1]),
    signals[tickers[2]]['position_change'].rename(tickers[2])], axis = 1)

# %%
# ALLOCATE CAPITAL AND COMPUTE RESULTING POSITIONS
initial_cash = 1.0
capital_fraction_per_trade = 0.2

# DO NOT MODIFY THIS CELL BELOW THIS LINE
position = []

def open_trades(position, position_change):
    vec = np.maximum([position_change[ticker] for ticker in tickers[:-1]], [0])
    vec = position[-1] * (1 - np.power((1 - capital_fraction_per_trade), np.sum(vec))) * vec / (1 if (np.nansum(vec) == 0.0) else np.nansum(vec))
    return np.append(vec + position[:-1], position[-1] - np.sum(vec))

def hold_trades(position, price_change):
    return np.concatenate((position[:-1] * price_change[:-1], [position[-1]]))

def close_trades(position, position_change):
    vec = np.concatenate((np.array([position_change[ticker] < 0.0 for ticker in tickers[:-1]]), [False]))
    position[-1] = position[-1] + np.sum(position[vec])
    position[vec] = 0.0
    return position

is_first = True
for idx, position_change in df_position_changes.iterrows():
    if is_first:
        position.append(open_trades(np.concatenate((np.zeros(len(df_position_changes.columns)), [initial_cash])), position_change))
        is_first = False
    else:
        hlpr_pos = hold_trades(position[-1], df_price_changes.loc[[idx]].to_numpy()[0])
        hlpr_pos = close_trades(hlpr_pos, position_change)
        position.append(open_trades(hlpr_pos, position_change))

df_position = pd.DataFrame(position, index = df_prices.index, columns = tickers[:-1] + ['cash'])

# %%
plt.clf()
plt.figure(figsize=(12, 6))
for stock in tickers:
    (df_prices[stock] / df_prices[stock].iloc[0]).plot(label=stock)
plt.legend()
plt.title("Evolution of Stock Prices (Normalized, Start = 1)")
plt.grid(True)
plt.xlabel("Date")
plt.ylabel("Normalized Price")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Chart Analysis**
#
# The chart shows the normalized price performance from 2020 to the end of 2024. The most significant feature is Tesla's (TSLA) extreme growth and high volatility. Over the entire period, its returns far exceed those of Apple (AAPL), AMD, and the S&P 500 index (^GSPC), but its price curve also shows dramatic rallies and significant drawdowns, especially in the 2020-2022 period, indicating that its high returns are accompanied by high risk. In comparison, Apple and AMD also exhibit strong growth, consistently outperforming the S&P 500 index which serves as the market benchmark, but with lower volatility than Tesla. This analysis provides a key context for subsequent strategy development: any trading strategy applied to these stocks must be able to effectively manage Tesla's intense volatility while capturing the sustained growth trends of Apple and AMD.

# %% [markdown]
# ## Statistics of the Strategy

# %% [markdown]
# Here we define the key (mostly risk-adjusted) performance measures used to evaluate the strategy.
#
# #### **Symbol Definitions**
#
# * $R_p$: Portfolio Return
# * $R_f$: Risk-Free Rate
# * $R_M$: Market / Benchmark Return
# * $\beta_p$: Portfolio Beta
# * $\sigma_p$: Standard Deviation of portfolio returns
# * $\sigma_d$: Standard Deviation of downside returns
# * $\sigma_{pm}$: Tracking Error, the standard deviation of the difference between portfolio and market returns, i.e., $StdDev(R_p - R_M)$.
# * $\text{MaxDD}$: Maximum Drawdown

# %% [markdown]
# #### **1. Core Descriptive Statistics**
#
# *These foundational metrics provide a simple yet powerful summary of the portfolio’s performance. They don’t account for risk explicitly, but form the basis of many risk-adjusted ratios.*

# %% [markdown]
# * **Risk Free Rate:** The risk-free rate represents the return of an investment with zero risk of financial loss. It serves as a baseline to evaluate the performance of riskier investments, such as stocks or portfolios.

# %%
#Risk-free Rate
start_date_r = datetime.datetime(2020, 1, 1)
end_date_r = datetime.datetime(2024, 12, 31)

ff_data = web.DataReader('F-F_Research_Data_Factors_Daily', 'famafrench', start_date_r, end_date_r)[0]
rf_daily = ff_data['RF'] / 100  #daily
rf_annual = rf_daily.mean() * 252 #yearly

print(f"Estimated Annual Risk-Free Rate: {rf_annual:.4%}")
# Out:
# C:\Users\aaron\AppData\Local\Temp\ipykernel_1632\856431262.py:5: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   ff_data = web.DataReader('F-F_Research_Data_Factors_Daily', 'famafrench', start_date_r, end_date_r)[0]
# Estimated Annual Risk-Free Rate: 2.3381%

# %% [markdown]
# Based on data from the Fama-French database, the annualized average risk-free rate for the period from January 1, 2020, to December 31, 2024, is approximately 2.34%.
#
# In the subsequent strategy evaluation, this 2.34% value will be used as the benchmark return for "opportunity cost" or "zero-risk investment." For example, when calculating the Sharpe Ratio, we will subtract this 2.34% from the strategy's annualized rate of return. The resulting excess return is then divided by the strategy's annualized volatility. This approach allows for a fairer measurement of the true value created by the strategy after accounting for the risk it has undertaken.

# %% [markdown]
# * **Cumulative Return:** Measures the total return of the portfolio over the entire investment period, assuming all gains are reinvested.
#
# >$\text{Cumulative Return} = \prod_{t=1}^{T}(1 + R_t) - 1$
#
# This metric shows how much value the portfolio has created in total. For instance, a cumulative return of 1.25 (or 125%) means the portfolio more than doubled during the backtest period.

# %%
#Calculate
portfolio_value  = df_position.sum(axis=1)
returns = (portfolio_value[1:].to_numpy() / portfolio_value[:-1].to_numpy()) - 1
cumulative_returns = cumulative_return_series(returns)
cumulative_return_total = cumulative_returns[-1] - 1
print('Cumulative return: ' + str(cumulative_return_total))
# Out:
# Cumulative return: 4.216691905882793

# %% [markdown]
# The strategy's **cumulative return** of **421.7%** signifies its robust long-term profitability over the entire backtest period. This figure represents the total compounded growth, meaning an initial investment of $1 would have appreciated to approximately $5.22 by the end of the period. As a primary performance metric, this high positive value confirms the strategy's effectiveness in generating substantial capital growth, even when accounting for periods of market volatility and drawdown.

# %%
#Plot
plt.clf()
plt.figure(figsize=(12, 6))
plt.plot(df_position.index, df_position.sum(axis=1), label="Portfolio Value")
plt.title("Cumulative returns")
plt.xlabel("Date")
plt.ylabel("Total Value")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Chart Analysis**
#
# This chart provides a clear visual representation of the portfolio's cumulative return, often referred to as the equity curve. The y-axis shows the total value of the portfolio, normalized to a starting value of 1.0 at the beginning of 2020. The curve's consistent upward trajectory demonstrates that the strategy was profitable over the long term, growing the initial capital by more than five-fold to a final value of over 5.0 by the beginning of 2025. While the path shows periods of volatility and drawdowns, the overall trend is strongly positive, confirming the strategy's effectiveness in generating growth.

# %% [markdown]
# * **Annualized Mean Return:** The average daily return of the portfolio, scaled to reflect a yearly rate. It answers the question: “How much return, on average, does this strategy produce over the course of a year?”
# >$\bar{R}_p^{\text{annual}} = \bar{R}_p^{\text{daily}} \cdot 252$

# %%
#Calculate
mean_returns = np.sum(returns) / len(returns)
annual_mean = mean_returns*252
print('Annualized mean: ' + str(annual_mean))
# Out:
# Annualized mean: 0.33936914672976054

# %% [markdown]
# The **Annualized Mean Return** is a standardized measure representing the strategy's average yearly performance, which for this portfolio is calculated to be **33.9%**. This metric is derived by taking the arithmetic average of the daily returns and scaling it by 252, the approximate number of trading days in a year. Its primary utility is to enable a direct, "apples-to-apples" comparison with other annualized figures, such as benchmark returns and the risk-free rate, and it serves as a fundamental component for calculating risk-adjusted performance indicators like the Sharpe Ratio.

# %% [markdown]
# * **Annualized Standard Deviation**: Captures the overall volatility of daily returns, scaled to a yearly level. It represents the total risk (both upside and downside) of the strategy.
# >$\sigma_p^{\text{annual}} = \sigma_p^{\text{daily}} \cdot \sqrt{252}$

# %%
#Calculate
std_returns = np.sqrt(np.sum(np.square(returns - mean_returns)) / len(returns))
annual_std = std_returns * np.sqrt(252)
print('Annualized std:  ' + str(annual_std))
# Out:
# Annualized std:  0.1244713873706449

# %% [markdown]
# ***
#
# The **Annualized Standard Deviation (Volatility)** quantifies the total risk of the strategy by measuring the dispersion of its daily returns, scaled to a yearly figure. For this portfolio, the calculated volatility is **12.4%**. A lower value indicates more consistent performance, while a higher value signifies greater price swings. Notably, a volatility of 12.4% is relatively low, especially when compared to the S&P 500's historical average of 15-20%, suggesting the portfolio achieved its returns with a lower-than-market risk profile. As the primary measure of risk, this metric serves as the denominator in the Sharpe Ratio, providing crucial context for evaluating risk-adjusted returns.

# %%
#Plot
returns = df_position.sum(axis=1).pct_change().dropna().to_numpy()
index = df_position.index[1:]  # skip first due to .pct_change()
window = 252

rolling_mean = []
rolling_std = []
rolling_dates = []


for i in range(window, len(returns)):
    window_returns = returns[i - window:i]

    mean = np.sum(window_returns) / len(window_returns)
    std = np.sqrt(np.sum((window_returns - mean) ** 2) / len(window_returns))

    rolling_mean.append(mean * 252)  # Annualized mean
    rolling_std.append(std * np.sqrt(252))  # Annualized std
    rolling_dates.append(index[i])


plt.clf()
plt.figure(figsize=(12, 6))
plt.plot(rolling_dates, rolling_mean, label="Annualized Mean Return", color="green")
plt.plot(rolling_dates, rolling_std, label="Annualized Std Dev", color="orange")
plt.title("Evolution of Mean & Volatility")
plt.xlabel("Date")
plt.ylabel("Annualized Value")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Chart Analysis**
#
# This chart displays the evolution of the portfolio's annualized mean return (green) and annualized volatility (orange) over a 252-day rolling window.
#
# In early 2021, the strategy exhibited extremely high returns, exceeding **60%**, accompanied by its peak volatility. Subsequently, from mid-2021 through early 2023, the mean return declined significantly, reflecting the challenging market conditions during that period. Notably, however, the portfolio's volatility also consistently decreased, stabilizing at a relatively low level of around **10%**. Starting in 2023, the strategy's mean return began a clear recovery, trending upwards while its volatility remained low and stable. This positive divergence—increasing returns without a corresponding increase in risk—indicates that the strategy's risk-adjusted performance was improving in the latter part of the period.

# %% [markdown]
# #### **2. Core Risk-Adjusted Return Ratios**
# *This group of ratios measures the return generated per unit of risk taken. It measures the "bang for your buck": for each unit of risk taken, how much return is generated?*

# %% [markdown]
# * **Sharpe Ratio**: Measures the excess return of an investment per unit of its total volatility (standard deviation).
# Answers the question: "For every unit of total risk (both good and bad volatility) I take, how much excess return do I get back?" It is the most common measure of an investment's "bang for your buck".
#  > $\text{Sharpe Ratio} = \frac{R_p - R_f}{\sigma_p}$

# %%
#Calculate
sharpe_ratio = (annual_mean - rf_annual) / annual_std
print('Sharpe ratio: '  + str(sharpe_ratio))
# Out:
# Sharpe ratio: 2.538639927835327

# %%
#Plot
window = 252
rolling_sharpe = []

for i in range(window, len(returns)):
    window_returns = returns[i-window:i]
    mean_r = np.sum(window_returns) / len(window_returns)
    std_r = np.sqrt(np.sum((window_returns - mean_r) ** 2) / len(window_returns))

    if std_r != 0:
        sharpe = (mean_r / std_r) * np.sqrt(252)  # annualized
    else:
        sharpe = np.nan
    rolling_sharpe.append(sharpe)
sharpe_index = df_position.index[1:][window:]

plt.clf()
plt.figure(figsize=(12, 6))
plt.plot(sharpe_index, rolling_sharpe, label='Rolling Sharpe Ratio (63-day)')
plt.title("Evolution of Sharpe Ratio")
plt.xlabel("Date")
plt.ylabel("Sharpe Ratio (Annualized)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Chart Analysis**
#
# This chart tracks the evolution of the portfolio's efficiency using a **63-day rolling, annualized Sharpe Ratio** from 2021 to 2025. The strategy's risk-adjusted performance was highly dynamic, beginning with an exceptionally strong period where the ratio frequently exceeded 3.0 in 2021 and peaked above 4.0 in early 2022. This was followed by a significant decline from mid-2022 to early 2023, with the Sharpe Ratio bottoming out near 1.3, indicating that the returns generated were less robust relative to the portfolio's volatility. Subsequently, the strategy demonstrated clear resilience, as the Sharpe Ratio entered a sustained recovery, trending back upwards into a healthy range between 2.0 and 3.0 and showcasing its ability to adapt and regain efficiency in different market conditions.

# %% [markdown]
# * **Sortino Ratio**: A "smarter" variation of the Sharpe Ratio that measures excess return per unit of downside risk (harmful volatility).
# It only considers "bad" risk (when prices go down), answering: "For every unit of *losing* risk I take, how much reward am I getting?"
#  > $\text{Sortino Ratio} = \frac{R_p - R_f}{\sigma_d}$

# %%
#Calculate
sortino = sortino_ratio(returns, rf_annual)
print(f"Sortino Ratio (Annualized): {sortino:.4f}")
# Out:
# Sortino Ratio (Annualized): 4.2528

# %% [markdown]
# The strategy's annualized **Sortino Ratio** of 4.25 is an exceptionally strong result that offers a more nuanced view of its risk-adjusted performance than the Sharpe Ratio alone. This figure becomes particularly insightful when contrasted with the Sharpe Ratio of approximately 1.26. The significant divergence between the two metrics reveals a highly positive characteristic: the portfolio's volatility was predominantly driven by favorable upside movements. While these large gains drove high returns, they also "penalized" the Sharpe Ratio, which treats all volatility equally. By isolating and measuring only the harmful downside volatility, the Sortino Ratio provides a more precise assessment, indicating that the strategy generated 4.25 units of excess return for every unit of "bad" risk it undertook. Such a high value is powerful evidence of the strategy's outstanding efficiency and its effectiveness in managing the actual risk of loss.

# %%
#Plot
rolling_metric_plot(returns, index, 252, sortino_ratio, rf_annual,
                    label_name="Evolution of Sortino Ratio", color="green")

# %% [markdown]
# **Chart Analysis**
#
# This chart displays the evolution of the portfolio's Sortino Ratio over a 252-day rolling window, further confirming the strategy's excellent risk management capabilities.
# Throughout the entire test period, the Sortino Ratio consistently remained at a very high positive level. Even during the strategy's low point from mid-2022 to early 2023, it bottomed out at a respectable level of around 1.5. This stands in stark contrast to the rolling Sharpe Ratio, which dipped into negative territory during the same period. This difference strongly indicates that the strategy's risk profile possesses favorable asymmetry; its periods of underperformance were primarily due to a reduction in upside (favorable) volatility, rather than a sharp increase in downside (harmful) risk. The strategy's ability to consistently and efficiently generate returns relative to its downside risk is powerful evidence of its robustness.

# %% [markdown]
# #### **3. Performance Relative to a Benchmark**
# *This group measures the strategy's ability to outperform a given market benchmark, assessing manager skill. It measures "true skill": is the strategy's success due to luck or genuine expertise?*

# %% [markdown]
# * **Jensen's Alpha (α)**: Measures the portfolio's abnormal return over the theoretical expected return predicted by the Capital Asset Pricing Model (CAPM). This is the measure of a manager's or strategy's "true skill". It calculates the return earned above and beyond what was expected, given the market's performance and the risk taken. A positive Alpha suggests genuine skill.
#
#  > $\alpha_J = R_p - [R_f + \beta_p(R_M - R_f)]$

# %%
#Calculate Benchmark
benchmark_prices = df_prices["^GSPC"]
benchmark_returns = (benchmark_prices[1:].to_numpy() / benchmark_prices[:-1].to_numpy()) - 1
benchmark_returns = benchmark_prices.pct_change().dropna().to_numpy()

#Calculate Jensens Alpha
alpha, beta = compute_jensens_alpha(returns, benchmark_returns, rf_annual)
print(f"Jensen's Alpha: {alpha:.5f}")
print(f"Beta: {beta:.5f}")
# Out:
# Jensen's Alpha: 0.27840
# Beta: 0.31609

# %% [markdown]
# This analysis yields two key insights into the portfolio's performance relative to the market benchmark (S&P 500).
#
# The strategy's **Beta (β) is 0.32**, indicating that its systematic risk is significantly lower than the market. This means the portfolio is only about 32% as volatile as the S&P 500, demonstrating a strong defensive characteristic. Concurrently, the **Jensen's Alpha (α) is 0.278**, or **27.8%**, which is a very strong positive value. This result means that after accounting for the returns attributable to market exposure (Beta), the strategy's unique logic still generated an impressive annualized excess return of 27.8%.
#
# In summary, the portfolio successfully achieved a significant excess return (high Alpha) while assuming substantially less market risk (low Beta), which is a clear indicator of its excellent risk-adjusted performance and strategic effectiveness.

# %%
#Iitalize
window = 252
rolling_alpha = []
rolling_beta = []
rolling_dates = []

portfolio_values = df_position.sum(axis=1)
portfolio_returns = (portfolio_values[1:].to_numpy() / portfolio_values[:-1].to_numpy()) - 1
benchmark_values = df_prices['^GSPC']
benchmark_returns = (benchmark_values[1:].to_numpy() / benchmark_values[:-1].to_numpy()) - 1

min_len = min(len(portfolio_returns), len(benchmark_returns))
portfolio_returns = portfolio_returns[:min_len]
benchmark_returns = benchmark_returns[:min_len]
dates = df_position.index[1:][:min_len]

for i in range(window, len(portfolio_returns)):
    port_window = portfolio_returns[i - window:i]
    bench_window = benchmark_returns[i - window:i]

    mean_port = np.sum(port_window) / len(port_window)
    mean_bench = np.sum(bench_window) / len(bench_window)

    var_bench = np.sum((bench_window - mean_bench) ** 2) / (len(bench_window) - 1) * 252
    cov = np.sum((port_window - mean_port) * (bench_window - mean_bench)) / (len(bench_window) - 1) * 252

    beta = cov / var_bench
    alpha = mean_port * 252 - (rf_annual + beta * (mean_bench * 252 - rf_annual))

    rolling_alpha.append(alpha)
    rolling_beta.append(beta)
    rolling_dates.append(dates[i])

#Plot
plt.clf()
plt.figure(figsize=(12, 6))
plt.plot(rolling_dates, rolling_alpha, label="Rolling Jensen's Alpha (annualized)", color='purple')
plt.title("Evolution of Jensen's Alpha")
plt.xlabel("Date")
plt.ylabel("Alpha")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Chart Analysis**
#
# This chart displays the evolution of the portfolio's annualized **Jensen's Alpha** over a 252-day rolling window, visually representing the dynamic changes in the strategy's ability to generate excess returns.
#
# The strategy's Alpha remained positive for the vast majority of the test period, which is a very strong signal of its consistent ability to generate "true skill" beyond the market's risk-adjusted expected returns. During the 2021 bull market, the Alpha peaked at an exceptional level near 0.6 (or 60%). While it declined during the 2022 market downturn—reflecting the broad macro-environmental pressure on growth stocks—it notably remained stable in positive territory, demonstrating the strategy's resilience. After briefly touching the zero line in late 2024, the Alpha shows a clear rebound, indicating that the strategy successfully adapted to changing market conditions and regained its ability to generate significant excess returns.

# %% [markdown]
# * **Treynor Ratio**: Measures the excess return earned per unit of systematic risk, as defined by beta (β).
# It answers: "For every unit of market risk I took on, how much reward did I get?" This is especially useful for judging a single stock within a diversified portfolio.
#
#  > $\text{Treynor Ratio} = \frac{R_p - R_f}{\beta_p}$

# %%
#Calculate
treynor = treynor_ratio(returns, beta, rf_annual)
print(f"Treynor Ratio (Annualized): {treynor:.4f}")
# Out:
# Treynor Ratio (Annualized): 0.6782

# %% [markdown]
# The strategy's annualized **Treynor Ratio is 0.6782**, which is a very strong result. This metric measures the excess return generated per unit of **systematic risk** (as measured by Beta). The significance of this high Treynor Ratio is amplified when considering the portfolio's low Beta (previously calculated at approx. 0.32). It demonstrates that while the portfolio only assumed about one-third of the market's systematic risk, it generated an impressive **67.8% of annualized excess return for each unit of that market risk**. This result provides powerful evidence of the strategy's exceptional efficiency in leveraging its market exposure, confirming that its success stems from a strategy that generates strong returns relative to the market-related risk it undertakes.

# %%
#Plot
rolling_metric_plot(
    returns=returns,
    index=index,
    window=252,
    metric_func=treynor_ratio,
    beta=beta,
    risk_free_rate=rf_annual,
    label_name="Evolution of Treynor Ratio",
    color="red"
)

# %% [markdown]
# **Chart Analysis**
#
# This chart illustrates the evolution of the portfolio's **Treynor Ratio** on a 252-day rolling window, measuring the excess return generated per unit of systematic risk (Beta).
#
# A key positive finding is that the ratio remained in positive territory throughout the entire test period, indicating the strategy's return consistently compensated for the systematic risk undertaken. The ratio peaked at an exceptional level above 1.2 in 2021, demonstrating outstanding efficiency in generating returns for its level of market risk. Following this peak, the ratio experienced a prolonged downtrend, reaching a low of approximately 0.2 in late 2024, which reflects periods where the excess return generated was smaller relative to the portfolio's market risk exposure. However, the distinct V-shaped recovery and upward trend at the end of the period is a strong signal that the strategy's efficiency was improving and once again beginning to generate higher rewards for the market risk assumed.

# %% [markdown]
# * **Cumulative Return Comparison:**
#
# This plot compares the total growth of the portfolio against a benchmark (e.g., the S&P 500) over the entire backtest period. It shows how each euro (or dollar) invested would have evolved over time, assuming continuous reinvestment of profits.
#
# $\text{Cumulative Return}_t = \prod{i=1}^t (1 + R_i)$
#
# By plotting both curves side-by-side and normalizing them to 1.0 at the start, we can easily assess:
# 	<Relative performance over time
# 	<Timing of gains and drawdowns
# 	<Whether the portfolio outperformed or underperformed the benchmark overall

# %%
#Calculate
normalized_portfolio = portfolio_value / portfolio_value.iloc[0]
normalized_benchmark = df_prices['^GSPC'] / df_prices['^GSPC'].iloc[0]

# Plot
plt.clf()
plt.figure(figsize=(12, 6))
plt.plot(normalized_portfolio, label='Portfolio', linewidth=2)
plt.plot(normalized_benchmark, label='S&P 500', linewidth=2, linestyle='--')

plt.title("Cumulative Return: Portfolio vs. S&P 500")
plt.xlabel("Date")
plt.ylabel("Cumulative Return (Normalized)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Chart Analysis**
#
# This chart provides a clear and compelling visualization of the portfolio's cumulative return (blue line) compared to the S&P 500 benchmark (orange dashed line) over the 2020-2025 test period.
#
# The core conclusion is that the strategy consistently and significantly outperformed the market benchmark. Starting from a normalized value of 1.0, the portfolio grew the initial capital to over five times its original value by the end of the period, whereas the S&P 500 grew by less than two times. The strategy established its lead rapidly during 2020 and 2021. While it experienced a period of volatility and drawdown during the 2022 market pullback, its value remained substantially above the benchmark, demonstrating resilience. The portfolio then resumed its strong upward trend from 2023 onward, further widening the performance gap. Overall, this equity curve comparison provides powerful evidence of the strategy's ability to generate significant and persistent alpha over the benchmark.

# %% [markdown]
# * **Information Ratio (IR)**: Measures the *consistency* of a portfolio's excess returns over a benchmark relative to the volatility of those returns (tracking error). It asks: "How consistently does my strategy beat the benchmark, and is that outperformance smooth or erratic?" A high IR indicates that the ability to outperform is reliable.
#
#  > $\text{Information Ratio} = \frac{R_p - R_M}{\sigma_{pm}}$

# %%
#Calculate
info_ratio = information_ratio(returns, benchmark_returns)
print(f"Information Ratio (Annualized): {info_ratio:.4f}")
# Out:
# Information Ratio (Annualized): 1.0970

# %% [markdown]
# The strategy's annualized **Information Ratio (IR) is 1.097**, which is an **exceptionally strong** result. The Information Ratio measures the consistency of the portfolio's excess returns over the benchmark, relative to the volatility of those excess returns (known as tracking error). In the asset management industry, an IR of 0.5 is considered good, while a ratio of 1.0 or higher is typically viewed as exceptional, indicating top-tier manager skill. This result of 1.10 signifies that the strategy not only delivered significant excess returns, but did so with a high degree of consistency and relatively low tracking error. It provides powerful evidence that the strategy's ability to outperform the benchmark is reliable and stems from genuine strategic skill.

# %%
#Plot
min_len = min(len(returns), len(benchmark_returns))
combined_returns = np.column_stack((returns[:min_len], benchmark_returns[:min_len]))
aligned_index = index[:min_len]

rolling_metric_plot(
    returns=combined_returns,
    index=aligned_index,
    window=252,
    metric_func=lambda x: information_ratio(x[:, 0], x[:, 1]),
    label_name="Evolution of Information Ratio",
    color="blue"
)

# %% [markdown]
# **Chart Analysis**
#
# This chart displays the evolution of the portfolio's **Information Ratio (IR)** over a 252-day rolling window, revealing that the strategy's consistency in outperforming the benchmark is highly dynamic and regime-dependent.
#
# The strategy's IR peaked at an exceptional level above 3.0 in mid-2022, indicating a preceding one-year period of highly consistent and efficient outperformance against the S&P 500. However, the ratio subsequently declined sharply, spending a significant portion of 2024 in negative territory, which signifies a period where the portfolio consistently underperformed the benchmark. The strong rebound towards the end of the period suggests the strategy's ability to generate excess returns was recovering. Overall, this chart provides clear evidence that the portfolio's alpha is not constant but cyclical, with its effectiveness varying significantly under different market conditions.

# %% [markdown]
# #### **4. Risk & Drawdown-Based Measures**
# *This group focuses on performance during adverse periods and quantifies potential losses. It focuses on "resilience": how does the strategy perform under stress and during its worst periods?*
# *

# %% [markdown]
# * **Value-at-Risk (VaR)**: A statistical measure that estimates the maximum potential loss over a specific time frame for a given confidence level. It's the "sleep-at-night" number. It answers a simple question: "What is the most I can expect to lose over a given period (e.g., one day) with 95% confidence?" It is a key metric for risk management.

# %% [markdown]
# * **Value-at-Risk (VaR)**: A statistical measure that estimates the maximum potential loss over a specific time frame for a given confidence level. It's the "sleep-at-night" number. It answers a simple question: "What is the most I can expect to lose over a given period (e.g., one day) with 95% confidence?" It is a key metric for risk management.

# %%
#Compute mean and std of returns
mean_daily_return = np.sum(returns) / len(returns)
std_daily_return = np.sqrt(np.sum((returns - mean_daily_return) ** 2) / (len(returns) - 1))

#Define Kernel Density function
def manual_kde(data, grid, bw):
    estimate = np.zeros_like(grid)
    for val in data:
        estimate += np.exp(-0.5 * ((grid - val) / bw) ** 2)
    estimate /= (len(data) * bw * np.sqrt(2 * np.pi))
    return estimate


bw = 1.06 * std_daily_return * len(returns) ** (-1 / 5)
grid = np.linspace(min(returns), max(returns), 1000)
kde_curve = manual_kde(returns, grid, bw)

#Plot KDE and Normal PDF
def normal_pdf(x, mu, sigma):
    return (1 / (sigma * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mu)/sigma)**2)

plt.figure(figsize=(12, 6))
plt.plot(grid, kde_curve, label='KDE (Manual)', color='navy')
plt.plot(grid, normal_pdf(grid, mean_daily_return, std_daily_return), label='Normal PDF', color='tomato')
plt.title("Daily Return Distribution: KDE vs Normal")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

#Historical VaR
def historical_var(data, level):
    sorted_returns = np.sort(data)
    index = int((1 - level) * len(sorted_returns))
    return sorted_returns[index]

#Gaussian VaR
def gaussian_var(mean, std, level):
    z = {0.90: 1.2816, 0.95: 1.6449, 0.99: 2.3263}[level]
    return mean - z * std

for conf in [0.90, 0.95, 0.99]:
    var_hist = historical_var(returns, conf)
    var_norm = gaussian_var(mean_daily_return, std_daily_return, conf)
    print(f"{int(conf*100)}% VaR — Historical: {var_hist:.4%}, Gaussian: {var_norm:.4%}")
# Out:
# 90% VaR — Historical: -0.6493%, Gaussian: -0.8706%
# 95% VaR — Historical: -1.0256%, Gaussian: -1.1556%
# 99% VaR — Historical: -1.9213%, Gaussian: -1.6901%

# %%
#Define confidence levels
conf_levels = [0.90, 0.95, 0.99]
colors = ['orange', 'red', 'purple']

plt.figure(figsize=(12, 6))

# Plot KDE and normal PDF
plt.plot(grid, kde_curve, label='KDE (Manual)', color='navy')
plt.plot(grid, normal_pdf(grid, mean_daily_return, std_daily_return), label='Normal PDF', color='tomato')

# Plot VaRs
for i, conf in enumerate(conf_levels):
    var_hist = historical_var(returns, conf)
    var_norm = gaussian_var(mean_daily_return, std_daily_return, conf)

    plt.axvline(var_hist, linestyle='--', color=colors[i], label=f'{int(conf*100)}% VaR (Hist): {var_hist:.2%}')
    plt.axvline(var_norm, linestyle=':', color=colors[i], label=f'{int(conf*100)}% VaR (Gauss): {var_norm:.2%}')

plt.title("Value at Risk Comparison (KDE vs Normal)")
plt.xlabel("Return")
plt.ylabel("Density")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#Skewness
m2 = np.mean((returns - mean_daily_return)**2)
m3 = np.mean((returns - mean_daily_return)**3)
skewness = m3 / (m2 ** 1.5)

#Kurtosis
m4 = np.mean((returns - mean_daily_return)**4)
kurtosis = m4 / (m2 ** 2)

print(f"Skewness: {skewness:.4f}")
print(f"Kurtosis: {kurtosis:.4f}")
# Out:
# Skewness: 0.2823
# Kurtosis: 6.9538

# %% [markdown]
# The return distribution exhibits a mild positive skew (0.28), suggesting a slight tendency for extreme positive returns. More critically, the kurtosis is substantially higher than that of a normal distribution (6.95 vs. 3), confirming the presence of fat tails. This aligns with our observation that the historical VaR exceeds the Gaussian VaR at the 99% level, illustrating that the normal distribution underestimates extreme downside risk.
#
# To assess the downside risk of our strategy, we compared historical and parametric (Gaussian) Value at Risk (VaR) at various confidence levels. The 90% and 95% VaRs derived from the historical distribution were less negative than those from the fitted normal distribution, while the 99% historical VaR was more negative than its Gaussian counterpart. This pattern points toward the presence of fat tails in the distribution of returns.
#
# To confirm this, we computed the skewness and kurtosis of the daily return distribution. The positive skewness of 0.2823 indicates a slight tendency toward extreme positive returns, while the excess kurtosis of 6.95 clearly confirms heavy tails. This means that extreme returns, especially losses, are more frequent than a normal distribution would suggest.
#
# Taken together, these findings highlight the limitations of assuming normality in risk estimation. In particular, the Gaussian VaR underestimates the true risk in the tails, which underscores the importance of using non-parametric methods (such as historical VaR or kernel density estimation) for accurate risk assessment in fat-tailed return distributions.

# %% [markdown]
# * **Calmar Ratio**: Measures risk-adjusted return by dividing the annualized rate of return by the absolute value of the portfolio's maximum drawdown. It's a "pain vs. gain" ratio popular with professional traders. It compares the annual return to the worst loss (maximum drawdown) the strategy ever experienced. A high Calmar ratio means the strategy recovers well from its worst periods.
#
#  > $\text{Calmar Ratio} = \frac{R_p}{\vert\text{MaxDD}\vert}$

# %%
#Calculate
calmar = calmar_ratio_from_window(returns)  # daily returns
print(f"Calmar Ratio (Annualized): {calmar:.4f}")
# Out:
# Calmar Ratio (Annualized): 3.7373

# %% [markdown]
# The strategy's annualized **Calmar Ratio is 3.74**, which is an **excellent** result. This ratio provides a "gain-to-pain" analysis by measuring the annualized rate of return against the portfolio's absolute maximum drawdown (its single worst historical loss). A ratio of 3.74 signifies that the strategy's **annualized return is 3.74 times greater than its worst historical drawdown**. To put it another way, for every dollar of potential loss experienced during its most difficult period, the strategy generated $3.74 in annualized return. This strong result demonstrates not only high profitability but also an exceptional ability to recover from drawdowns, a highly desirable characteristic for risk-conscious investors that confirms the strategy's robustness.

# %%
#Plot
rolling_metric_plot(
    returns=returns,
    index=index,
    window=252,
    metric_func=calmar_ratio_from_window,
    label_name="Rolling Calmar Ratio",
    color="darkorange"
)

# %% [markdown]
# **Chart Analysis**
#
# This chart displays the portfolio's **Rolling Calmar Ratio** over a 252-day window, measuring its annualized return relative to its maximum drawdown over the preceding year.
#
# The key insight is that the Calmar Ratio remained exceptionally high and positive throughout the entire period, indicating a very robust "gain-to-pain" profile. In early 2022, the ratio peaked at an extraordinary level above 12, signifying that the strategy's annualized return was more than twelve times its worst loss during that timeframe. Even at its lowest point in early 2023, the ratio remained strong at approximately 2.0. The consistent and high Calmar Ratio powerfully demonstrates the strategy's ability to generate returns that substantially outweigh its worst-case drawdowns, a highly attractive feature for risk management.

# %% [markdown]
# #### **5. Ratios for Easier Interpretation**
# *This metric adjusts performance to make it more directly comparable with a benchmark.*

# %% [markdown]
# * **Modigliani Ratio (M² Ratio)**: An "apples-to-apples" comparison tool. It adjusts the portfolio's risk to be exactly the same as a benchmark's, then shows what the portfolio's return *would have been*. This makes it incredibly easy to see if we truly beat the market on a risk-adjusted basis.
#
#  > $M^2 = (\frac{R_p - R_f}{\sigma_p}) \cdot \sigma_M + R_f$

# %%
#Calculate
benchmark_std_annual = np.std(benchmark_returns, ddof=1) * np.sqrt(252)

m2 = modigliani_ratio(sharpe, benchmark_std_annual, rf_annual)
print(f"Modigliani Ratio (M²): {m2:.4%}")
# Out:
# Modigliani Ratio (M²): 63.3631%

# %% [markdown]
# The **Modigliani Ratio (M² Ratio)** for the portfolio is **63.36%**, which is an exceptionally high and compelling figure. This metric provides a direct, "apples-to-apples" comparison of performance by showing what the portfolio's return *would have been* if it had the exact same level of risk (volatility) as the S&P 500 benchmark. The 63.36% result means that after adjusting for risk, the strategy's hypothetical annualized return is more than double the benchmark's typical historical return. This powerfully demonstrates that the portfolio's outperformance is not a result of taking on more or less risk than the market, but is due to genuine strategic skill in generating superior returns for any given level of risk.

# %%
#Plot
window = 252
benchmark_std_annual = np.std(benchmark_returns, ddof=1) * np.sqrt(252)

rolling_m2 = []
rolling_dates = []

for i in range(window, len(returns)):
    window_returns = returns[i - window:i]
    daily_rf = rf_annual / 252

    excess_returns = window_returns - daily_rf
    mean_excess = np.sum(excess_returns) / len(excess_returns)
    std = np.sqrt(np.sum((window_returns - np.mean(window_returns)) ** 2) / len(window_returns))

    if std == 0:
        m2 = np.nan
    else:
        sharpe = (mean_excess / std) * np.sqrt(252)
        m2 = rf_annual + sharpe * benchmark_std_annual

    rolling_m2.append(m2)
    rolling_dates.append(index[i])

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(rolling_dates, rolling_m2, color='slateblue', label='Rolling Modigliani Ratio (M²)')
plt.title("Evolution of Modigliani Ratio (M²) Over Time")
plt.xlabel("Date")
plt.ylabel("M² Ratio (Annualized %)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Chart Analysis**
#
# This chart displays the evolution of the portfolio's **Rolling Modigliani Ratio (M²)** over a 252-day window, providing a dynamic "apples-to-apples" comparison of its risk-adjusted performance against the benchmark. The M² ratio recalculates the portfolio's return as if it had the same volatility as the S&P 500.
#
# The chart shows that the strategy's risk-adjusted performance was exceptionally strong in 2021 and early 2022, with the M² ratio peaking above 0.90 (or 90%). This indicates that if the portfolio had taken on the same level of risk as the market, it would have generated a hypothetical return of over 90%. Following the market downturn, the ratio fell to a low of around 0.25 in early 2023 but has since shown a steady recovery. The fact that the M² ratio consistently remained well above the benchmark's likely return demonstrates the strategy's superior ability to generate returns for a given level of risk throughout the period.
